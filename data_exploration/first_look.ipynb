# %% [markdown]
# Links to Data Sources
#
# General Business:
# Issued Licenses -> https://data.cityofnewyork.us/Business/Issued-Licenses/w7w3-xahh/about_data
# License Apps -> https://data.cityofnewyork.us/Business/License-Applications/ptev-4hud/about_data
# Business Type (based on Issued Licenses) -> https://data.cityofnewyork.us/Business/Business-Type-Based-on-Legally-Operating-Businesse/pmxj-whmv
#
# Groceries -> https://data.ny.gov/Economic-Development/Retail-Food-Stores/9a8c-vfzj/about_data
#
# Pharmacy:
# Syringe Drop-Off -> https://catalog.data.gov/dataset/pharmaceutical-and-syringe-drop-off-locations-in-nyc
# Facilites -> https://data.cityofnewyork.us/City-Government/Facilities-Database/ji82-xba5/about_data
#
# Population:
# Data -> https://popfactfinder.planning.nyc.gov/explorer/cities/NYC?compareTo=1
# Tracts -> https://data.cityofnewyork.us/City-Government/2020-Census-Tracts/63ge-mke6/about_data

# %%
import pandas as pd

# %%
businesses = pd.read_csv('/Users/danylo/Repos/capstone/AmenityGap-NYC/data_exploration/data/Issued_Licenses_20260218.csv')
businesses.head()
# Out:
# /var/folders/1_/cybvzsy149s827970j9wcvh40000gn/T/ipykernel_17687/918858222.py:1: DtypeWarning: Columns (0: Street3) have mixed types. Specify dtype option on import or set low_memory=False.
#   businesses = pd.read_csv('/Users/danylo/Repos/capstone/AmenityGap-NYC/data_exploration/data/Issued_Licenses_20260218.csv')
#   License Number                           Business Name DBA/Trade Name  \
# 0    0016371-DCA                    JAMES ROBINSON, INC.            NaN
# 1    0157941-DCA                     T & J SALVAGE CORP.            NaN
# 2    0202454-DCA                S. BELLITTE & SONS, INC.            NaN
# 3    0225766-DCA              EMPIRE DIAMOND CORPORATION            NaN
# 4    0227765-DCA  HECHT SEWING MACHINE & MOTOR CO., INC.            NaN
#
#   Business Unique ID            Business Category License Type License Status  \
# 0    BA-1322274-2022  Secondhand Dealer - General     Premises         Active
# ...

# %%
businesses['Business Category'].value_counts()
# Out:
# Business Category
# Home Improvement Contractor                                 18116
# Tobacco Retail Dealer                                        6504
# Secondhand Dealer - General                                  5299
# Electronics Store                                            4087
# Sightseeing Guide                                            3764
# Tow Truck Driver                                             3027
# Locksmith                                                    2912
# Electronic Cigarette Dealer                                  2711
# Garage & Parking Lot                                         2655
# Stoop Line Stand                                             2595
# General Vendor                                               2403
# Dealer In Products For The Disabled                          2111
# Debt Collection Agency                                       2067
# Pedicab Driver                                               1916
# ...

# %%
businesses[businesses['Business Category'].str.contains('laundr', case=False, na=False)]
# Out:
#       License Number                       Business Name DBA/Trade Name  \
# 4363     2052730-DCA       Superior Uniform Services LLC            NaN
# 13207    2052087-DCA            PURRFECT ENTERPRISES INC            NaN
# 24769    2047591-DCA       FDR SERVICES CORP OF NEW YORK            NaN
# 24800    2047676-DCA  A&P Coat, Apron & Linen Supply LLC            NaN
# 24821    2047785-DCA                 RJ Linen & Uniforms            NaN
# ...              ...                                 ...            ...
# 67877    2069063-DCA              FS LAUNDRY CORPORATION       WASHCLUB
# 67918    2075568-DCA        FIRST GOLDEN EAGLE GROUP INC   LAUNDRY KING
# 67946    2080943-DCA          Yankee Linen Service, Inc.            NaN
# 68070   2132909-DCWP                  Loving Laundry LLC            NaN
# 68377    2047717-DCA            Cintas Corporation No. 2            NaN
#
#       Business Unique ID            Business Category License Type  \
# ...

# %%
businesses[businesses['Business Name'].str.contains('laundr', case=False)]
# Out:
#       License Number                        Business Name  \
# 12688    1366613-DCA           DIRECT LAUNDRY SYSTEM INC.
# 12689    1366622-DCA           DIRECT LAUNDRY SYSTEM INC.
# 12887    1374836-DCA  SUPERIOR LAUNDRY EQUIPMENT NY, INC.
# 12937    1376109-DCA               HANNAH LAUNDROMAT INC.
# 14745    1418453-DCA  SUPERIOR LAUNDRY EQUIPMENT NY, INC.
# 15174    1427639-DCA            SKY LAUNDRY SYSTEMS CORP.
# 21039    2025427-DCA               KINGS BORO LAUNDRY INC
# 22959    2036473-DCA       JUQUILITA LAUNDRY & DELI CORP.
# 27893    2065106-DCA          MAMAS UNIFORM LAUNDRY, INC.
# 28610    2067506-DCA          Auto Laundry Car Wash Corp.
# 31312    2075994-DCA          LAUNDROMAT OF 36TH AVE INC.
# 31942    2078910-DCA           81 Family Laundromat Corp.
# 32171    2079742-DCA                  ESK LAUNDROMAT INC.
# 33725    2085188-DCA      NEW CHEN UP & UP LAUNDROMAT INC
# 35573    2092008-DCA                     Z LAUNDROMAT INC
# ...
